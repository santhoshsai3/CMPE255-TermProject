# %%
import matplotlib.pyplot as plt

# %%
mses = [1.266,1.265,1.21,1.28,5.4,5.23]
algos = ['KNN','KNN-GridSearchCV', 'SVD',"NMF",'cosine_Similarity','Jaccard_Similarity']
plt.plot(algos, mses, 'go',  )
plt.xlabel("Different algos")
plt.ylabel("MSE")
plt.show()
